# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("../Data/data.txt")
text = loader.load()
text
len(text)
oneDoc = text[0]
print(oneDoc.page_content)
# Out:
# abcdefghijklmnopqrstuwxyz

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("../Data/Dhaval_Tank_resume.pdf")
doc = loader.load()
doc
len(doc)
one_doc = doc[0]
print(one_doc.page_content)
# Out:
# D H A V A L  T A NK
# +91 9429290917 |  tankdhaval049@gmail.com |  Jamnagar, Gujarat  |  linkedin.com |   github.com
# P R O F E S S I O N A L  S U M M A R Y
# Motivated Software Developer with hands -on experience building web applications, REST APIs, and scalable
# software solutions through academic projects and internship experience. Skilled in frontend and backend
# development, database management, and modern web technologies. Passionate about solving real -world
# problems, writing clean and effici ent code, and continuously learning new technologies to build high -quality
# applications.
# S K I L L S
# Languages: Python · JavaScript · Java · C/C++ · PHP · Android
# Frameworks: Django · Flask · FastAPI
# Libraries: Pandas · Scikit-learn · Seaborn · NumPy
# Web Technologies: HTML · CSS · JavaScript · React.js · Node.js · Next.js · Bootstrap · Tailwind css
# SEO & Web Administration:  Google Analytics · Google Search Console · XML Sitemap Management · Cron Job
# ...

# %%
from langchain_community.document_loaders import CSVLoader
loader = CSVLoader("../Data/Book.csv")
csv = loader.load()
csv
len(csv)
# Out:
# 63

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader(web_path=" https://google.com")
docs = loader.load()
docs
docs[0].page_content
# Out:
# 'GoogleGmailImagesSign in\xa0Advanced searchGoogle offered in:  हिन्दी বাংলা తెలుగు मराठी தமிழ் ગુજરાતી ಕನ್ನಡ മലയാളം ਪੰਜਾਬੀ AdvertisingBusiness SolutionsAbout GoogleGoogle.co.in© 2026 - Privacy - TermsGoogle apps'

# %%
from langchain_community.document_loaders import WikipediaLoader
loader = WikipediaLoader(query="who is pm modi?",load_max_docs=2)
docs = loader.load()
docs
# docs[0].page_content
# Out:
# [Document(metadata={'title': 'PM Narendra Modi (film)', 'summary': "PM Narendra Modi is a 2019 Indian Hindi-language propaganda film. It was directed by Omung Kumar, written by Anirudh Chawla and Vivek Oberoi, and produced under the banner of Legend Studios. The film is a hagiography of Narendra Modi, the prime minister of India since 2014. Its original release schedule on the opening day of the 2019 Indian general election caused significant backlash, leading to the film being banned by the Election Commission of India (ECI) for the duration of the general election. It was only released after the election's conclusion, receiving overwhelmingly negative reviews from critics.", 'source': 'https://en.wikipedia.org/wiki/PM_Narendra_Modi_(film)'}, page_content='PM Narendra Modi is a 2019 Indian Hindi-language propaganda film. It was directed by Omung Kumar, written by Anirudh Chawla and Vivek Oberoi, and produced under the banner of Legend Studios. The film is a hagiography of Narendra M
# ...
