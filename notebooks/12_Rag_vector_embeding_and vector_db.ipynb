# %%
documents = [
    "Machine learning is a subset of artificial intelligence",
    "Deep learning uses neural networks with multiple layers",
    "Python is a programming language popular for data science",
    "India won the cricket world cup in 2011",
    "AI models can understand and generate human language"
]

from langchain_google_genai import GoogleGenerativeAIEmbeddings
embedding = GoogleGenerativeAIEmbeddings(
    model="gemini-embedding-2-preview"
)
vector = embedding.embed_query(documents)
len(vector)
# vector
# Out:
# 3072

# %%
from langchain_chroma import Chroma
vectore_store = Chroma.from_texts(
    texts = documents,
    embedding=embedding,
    persist_directory="./vector.db"
)

# %%
q = "Data Sceince"

res = vectore_store.similarity_search(query=q,k=2)
res
# Out:
# [Document(id='1b530993-f14c-444c-b994-bbfbafba04e2', metadata={}, page_content='Python is a programming language popular for data science'),
#  Document(id='de28ff14-2125-4dab-ae09-7feaedf166d8', metadata={}, page_content='Python is a programming language popular for data science')]
